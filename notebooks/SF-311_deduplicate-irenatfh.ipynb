# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Set library parameters

# %%
# Pandas display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ### Import raw top abandoned vehicles file

# %%
df_plates_top = pd.read_csv('../data/abandoned-vehicles_top20.csv')
df_plates_top.head()
# Out:
#    Unnamed: 0    index   CaseID               Opened               Closed  \
# 0  0           1458949  6146916  2016-08-02 08:00:35  2016-08-05 07:51:15
# 1  1           2049493  6127602  2016-07-27 13:53:26  2016-08-04 06:14:28
# 2  2           2050693  6124122  2016-07-26 16:02:36  2016-07-28 08:28:13
# 3  3           1842645  6011353  2016-06-23 12:29:20  2016-06-28 07:57:23
# 4  4           1865076  5936034  2016-06-02 15:30:16  2016-06-06 06:04:35
#
#                Updated  Status  \
# 0  2016-08-05 07:51:15  Closed
# 1  2016-08-04 06:14:28  Closed
# 2  2016-07-28 08:28:13  Closed
# 3  2016-06-28 07:57:23  Closed
# 4  2016-06-06 06:04:35  Closed
#
#                                                                         Status Notes  \
# 0  DPT Abandoned Vehicles- Gone on Arrival - 08/04/16  @1320         #211
# 1  DPT Abandoned Vehicles- Gone on Arrival - 08/03/16  @1200     #211
# 2  DPT Abandoned Vehicles- Gone on Arrival - 07/27/16  @1330     #211
# ...

# %%
plates = df_plates_top['Plate'].value_counts().sort_values(ascending=False)
plates.reset_index()
# Out:
#       index  Plate
# 0   4AHL026  146
# 1   3LXY721  115
# 2   6PUJ756  87
# 3   1RNW837  74
# 4   6PUK177  65
# 5   6XVM291  58
# 6   1PLM055  58
# 7   3XTE099  58
# 8   6SLZ243  56
# 9   7ZIB155  55
# 10  2GYE544  54
# 11  6AMP741  54
# 12  6MKG078  53
# 13  2JPU300  50
# 14  3EXG277  49
# 15  5HTH408  48
# 16  5NYL790  48
# 17  5PCJ006  47
# 18  4AIA248  46
# 19  7LSM393  44

# %% [markdown]
# ### Deduplication

# %% [markdown]
# Manually examine the all calls for each license plate and make notes of which ones to remove. In this notebook, I will deduplicate plates 0-9

# %%
# Create a copy of the top repeat plates dataframe in preparation for removing duplicates
df_plates_top_clean = df_plates_top.copy()

# %%
plate = '4AHL026'
# Show all cases, sort by Opened date
df_plates_top[df_plates_top['Plate'] == plate].sort_values('Opened')
# Drop cases that were noted to be duplicates in the Status Notes of another case
# # Cases marked as duplicate, but corresponding cases were already eliminated so keep these
duplicates_keep = [142, 89, 39]
# # Cases marked as duplicate and refer to another case, so can be safely dropped
duplicates = [134, 116, 98, 90, 71, 70, 65, 61, 58, 53, 50, 41, 32, 28, 22, 4]
# # Interesting cases
notable_cases = [56]  # Interesting Status Note
df_plates_top_clean.drop(duplicates, inplace=True)

# %%
plate = '3LXY721'
df_plates_top[df_plates_top['Plate'] == plate].sort_values('Opened')
duplicates = [229,210]
notable_cases = [251,249,209,207,206,198,196,193,174,173,167,160,151,146]  # Interesting Status Note
df_plates_top_clean.drop(duplicates, inplace=True)

# %%
plate = '6PUJ756'
df_plates_top[df_plates_top['Plate'] == plate].sort_values('Opened')
duplicates_keep = [304,297,295,276]
duplicates = [339,332,316,310,298,280,274,273,268,265,261]
notable_cases = [344]
df_plates_top_clean.drop(duplicates, inplace=True)

# %%
plate = '1RNW837'
df_plates_top[df_plates_top['Plate'] == plate].sort_values('Opened')
duplicates_keep = [392,368]
duplicates = [418,399,393,373,]
notable_cases = [406,399,398,396,395,394,383,379,375,374,372,371,370,367,366,365,364,360,356,355,354,353,352,351,350,349,348]
df_plates_top_clean.drop(duplicates, inplace=True)

# %%
plate = '6PUK177'
df_plates_top[df_plates_top['Plate'] == plate].sort_values('Opened')
duplicates_keep = [444,441,440,437,434,431,428,424]
duplicates = [466,464,449,446,445]
notable_cases = [467,465]
df_plates_top_clean.drop(duplicates, inplace=True)

# %% [markdown]
# Notes on plate 6XVM291:
# * Index 641, CaseID 2229606: Neighborhood dispute?
# * Index 502, CaseID 6137331: case transferred to whom?

# %%
plate = '6XVM291'
df_plates_top[df_plates_top['Plate'] == plate].sort_values('Opened')
duplicates = [513,492]
notable_cases = [542,541,538,536,535,502]
df_plates_top_clean.drop(duplicates, inplace=True)

# %% [markdown]
# Notes on plate 1PLM055
# * Index 547, CaseID 5491678: "NEIGHBOR DISPUTE"

# %%
plate = '1PLM055'
df_plates_top[df_plates_top['Plate'] == plate].sort_values('Opened')
duplicates = [601,592,570,567,563,562,548]
notable_cases = [596,595,594,590,587,584,571,563,559,556,554,547,546]
df_plates_top_clean.drop(duplicates, inplace=True)

# %% [markdown]
# Notes on plate 3XTE099
# * I'm not confident this is an abandoned vehicle. A) it's a sedan and B) it's often reported to be at virtually the same address.

# %%
plate = '3XTE099'
df_plates_top[df_plates_top['Plate'] == plate].sort_values('Opened')
duplicates_keep = []
duplicates = [637]
notable_cases = [642,633,632,631,628,621,619,617,616,615,614,613,]
df_plates_top_clean.drop(duplicates, inplace=True)

# %%
plate = '6SLZ243'
df_plates_top[df_plates_top['Plate'] == plate].sort_values('Opened')
duplicates_keep = []
duplicates = []
notable_cases = [711,694,682]

# %%
plate = '7ZIB155'
df_plates_top[df_plates_top['Plate'] == plate].sort_values('Opened')
duplicates = [759,749,747,721,]
duplicates_keep = [769,762,752,751,749,719]
df_plates_top_clean.drop(duplicates, inplace=True)
